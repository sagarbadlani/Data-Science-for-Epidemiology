# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# 2022-11-29 00:52:15.873532: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# fix random seed for reproducibility
tf.random.set_seed(7)

# %%
# Use a random dataset for testing
import pandas as pd
import matplotlib.pyplot as plt
dataframe = pd.read_csv('airline-passengers.csv', usecols=[1], engine='python')
plt.plot(dataframe)
plt.show()

# %%
# Change the dataset format to float
dataset = dataframe.values
dataset = dataset.astype('float32')

# Normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 96 48

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 10
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# print(trainX)

# for i in range(trainX.shape[0]):
#     print(i, trainX[i, 0], trainY[i])

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# 2022-11-29 00:52:18.653572: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-29 00:52:18.653837: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Epoch 1/100
# 85/85 - 2s - loss: 0.0179 - 2s/epoch - 26ms/step
# Epoch 2/100
# 85/85 - 1s - loss: 0.0062 - 584ms/epoch - 7ms/step
# Epoch 3/100
# 85/85 - 1s - loss: 0.0054 - 586ms/epoch - 7ms/step
# Epoch 4/100
# 85/85 - 1s - loss: 0.0049 - 525ms/epoch - 6ms/step
# Epoch 5/100
# 85/85 - 0s - loss: 0.0046 - 434ms/epoch - 5ms/step
# Epoch 6/100
# 85/85 - 0s - loss: 0.0047 - 411ms/epoch - 5ms/step
# Epoch 7/100
# 85/85 - 0s - loss: 0.0042 - 338ms/epoch - 4ms/step
# Epoch 8/100
# 85/85 - 0s - loss: 0.0041 - 418ms/epoch - 5ms/step
# Epoch 9/100
# 85/85 - 0s - loss: 0.0041 - 345ms/epoch - 4ms/step
# Epoch 10/100
# 85/85 - 0s - loss: 0.0039 - 323ms/epoch - 4ms/step
# Epoch 11/100
# 85/85 - 0s - loss: 0.0038 - 318ms/epoch - 4ms/step
# Epoch 12/100
# 85/85 - 0s - loss: 0.0038 - 326ms/epoch - 4ms/step
# Epoch 13/100
# 85/85 - 0s - loss: 0.0037 - 466ms/epoch - 5ms/step
# Epoch 14/100
# 85/85 - 0s - loss: 0.0036 - 393ms/epoch - 5ms/step
# Epoch 15/100
# 85/85 - 0s - loss: 0.0035 - 407ms/epoch - 5ms/step
# Epoch 16/100
# 85/85 - 0s - loss: 0.0035 - 417ms/epoch - 5ms/step
# Epoch 17/100
# 85/85 - 0s - loss: 0.0033 - 400ms/epoch - 5ms/step
# Epoch 18/100
# 85/85 - 0s - loss: 0.0034 - 398ms/epoch - 5ms/step
# Epoch 19/100
# 85/85 - 0s - loss: 0.0033 - 417ms/epoch - 5ms/step
# Epoch 20/100
# 85/85 - 0s - loss: 0.0032 - 402ms/epoch - 5ms/step
# Epoch 21/100
# 85/85 - 0s - loss: 0.0034 - 391ms/epoch - 5ms/step
# Epoch 22/100
# 85/85 - 0s - loss: 0.0031 - 340ms/epoch - 4ms/step
# Epoch 23/100
# 85/85 - 0s - loss: 0.0029 - 425ms/epoch - 5ms/step
# Epoch 24/100
# 85/85 - 0s - loss: 0.0029 - 445ms/epoch - 5ms/step
# Epoch 25/100
# 85/85 - 0s - loss: 0.0029 - 434ms/epoch - 5ms/step
# Epoch 26/100
# 85/85 - 0s - loss: 0.0029 - 337ms/epoch - 4ms/step
# Epoch 27/100
# 85/85 - 0s - loss: 0.0027 - 381ms/epoch - 4ms/step
# Epoch 28/100
# 85/85 - 0s - loss: 0.0027 - 390ms/epoch - 5ms/step
# Epoch 29/100
# 85/85 - 0s - loss: 0.0028 - 403ms/epoch - 5ms/step
# Epoch 30/100
# 85/85 - 0s - loss: 0.0026 - 412ms/epoch - 5ms/step
# Epoch 31/100
# 85/85 - 0s - loss: 0.0026 - 369ms/epoch - 4ms/step
# Epoch 32/100
# 85/85 - 0s - loss: 0.0026 - 348ms/epoch - 4ms/step
# Epoch 33/100
# 85/85 - 0s - loss: 0.0025 - 355ms/epoch - 4ms/step
# Epoch 34/100
# 85/85 - 0s - loss: 0.0025 - 391ms/epoch - 5ms/step
# Epoch 35/100
# 85/85 - 0s - loss: 0.0025 - 418ms/epoch - 5ms/step
# Epoch 36/100
# 85/85 - 0s - loss: 0.0025 - 293ms/epoch - 3ms/step
# Epoch 37/100
# 85/85 - 0s - loss: 0.0024 - 373ms/epoch - 4ms/step
# Epoch 38/100
# 85/85 - 0s - loss: 0.0023 - 409ms/epoch - 5ms/step
# Epoch 39/100
# 85/85 - 0s - loss: 0.0023 - 375ms/epoch - 4ms/step
# Epoch 40/100
# 85/85 - 0s - loss: 0.0022 - 394ms/epoch - 5ms/step
# Epoch 41/100
# 85/85 - 0s - loss: 0.0023 - 422ms/epoch - 5ms/step
# Epoch 42/100
# 85/85 - 0s - loss: 0.0023 - 374ms/epoch - 4ms/step
# Epoch 43/100
# 85/85 - 0s - loss: 0.0021 - 364ms/epoch - 4ms/step
# Epoch 44/100
# 85/85 - 0s - loss: 0.0022 - 367ms/epoch - 4ms/step
# Epoch 45/100
# 85/85 - 0s - loss: 0.0022 - 354ms/epoch - 4ms/step
# Epoch 46/100
# 85/85 - 0s - loss: 0.0020 - 341ms/epoch - 4ms/step
# Epoch 47/100
# 85/85 - 0s - loss: 0.0021 - 358ms/epoch - 4ms/step
# Epoch 48/100
# 85/85 - 0s - loss: 0.0021 - 330ms/epoch - 4ms/step
# Epoch 49/100
# 85/85 - 0s - loss: 0.0021 - 355ms/epoch - 4ms/step
# Epoch 50/100
# 85/85 - 0s - loss: 0.0020 - 377ms/epoch - 4ms/step
# Epoch 51/100
# 85/85 - 0s - loss: 0.0020 - 383ms/epoch - 5ms/step
# Epoch 52/100
# 85/85 - 0s - loss: 0.0021 - 382ms/epoch - 4ms/step
# Epoch 53/100
# 85/85 - 0s - loss: 0.0019 - 400ms/epoch - 5ms/step
# Epoch 54/100
# 85/85 - 0s - loss: 0.0018 - 341ms/epoch - 4ms/step
# Epoch 55/100
# 85/85 - 0s - loss: 0.0019 - 420ms/epoch - 5ms/step
# Epoch 56/100
# 85/85 - 0s - loss: 0.0020 - 364ms/epoch - 4ms/step
# Epoch 57/100
# 85/85 - 0s - loss: 0.0018 - 349ms/epoch - 4ms/step
# Epoch 58/100
# 85/85 - 0s - loss: 0.0017 - 313ms/epoch - 4ms/step
# Epoch 59/100
# 85/85 - 0s - loss: 0.0017 - 319ms/epoch - 4ms/step
# Epoch 60/100
# 85/85 - 0s - loss: 0.0017 - 419ms/epoch - 5ms/step
# Epoch 61/100
# 85/85 - 0s - loss: 0.0017 - 389ms/epoch - 5ms/step
# Epoch 62/100
# 85/85 - 0s - loss: 0.0019 - 363ms/epoch - 4ms/step
# Epoch 63/100
# 85/85 - 0s - loss: 0.0017 - 357ms/epoch - 4ms/step
# Epoch 64/100
# 85/85 - 0s - loss: 0.0018 - 318ms/epoch - 4ms/step
# Epoch 65/100
# 85/85 - 0s - loss: 0.0017 - 407ms/epoch - 5ms/step
# Epoch 66/100
# 85/85 - 0s - loss: 0.0016 - 384ms/epoch - 5ms/step
# Epoch 67/100
# 85/85 - 0s - loss: 0.0016 - 342ms/epoch - 4ms/step
# Epoch 68/100
# 85/85 - 0s - loss: 0.0015 - 334ms/epoch - 4ms/step
# Epoch 69/100
# 85/85 - 0s - loss: 0.0014 - 415ms/epoch - 5ms/step
# Epoch 70/100
# 85/85 - 0s - loss: 0.0018 - 381ms/epoch - 4ms/step
# Epoch 71/100
# 85/85 - 0s - loss: 0.0015 - 373ms/epoch - 4ms/step
# Epoch 72/100
# 85/85 - 0s - loss: 0.0015 - 374ms/epoch - 4ms/step
# Epoch 73/100
# 85/85 - 0s - loss: 0.0015 - 399ms/epoch - 5ms/step
# Epoch 74/100
# 85/85 - 0s - loss: 0.0015 - 381ms/epoch - 4ms/step
# Epoch 75/100
# 85/85 - 0s - loss: 0.0015 - 381ms/epoch - 4ms/step
# Epoch 76/100
# 85/85 - 0s - loss: 0.0015 - 421ms/epoch - 5ms/step
# Epoch 77/100
# 85/85 - 0s - loss: 0.0015 - 412ms/epoch - 5ms/step
# Epoch 78/100
# 85/85 - 0s - loss: 0.0015 - 417ms/epoch - 5ms/step
# Epoch 79/100
# 85/85 - 0s - loss: 0.0015 - 368ms/epoch - 4ms/step
# Epoch 80/100
# 85/85 - 0s - loss: 0.0016 - 367ms/epoch - 4ms/step
# Epoch 81/100
# 85/85 - 0s - loss: 0.0015 - 372ms/epoch - 4ms/step
# Epoch 82/100
# 85/85 - 0s - loss: 0.0014 - 410ms/epoch - 5ms/step
# Epoch 83/100
# 85/85 - 0s - loss: 0.0015 - 356ms/epoch - 4ms/step
# Epoch 84/100
# 85/85 - 0s - loss: 0.0014 - 322ms/epoch - 4ms/step
# Epoch 85/100
# 85/85 - 0s - loss: 0.0014 - 330ms/epoch - 4ms/step
# Epoch 86/100
# 85/85 - 0s - loss: 0.0014 - 356ms/epoch - 4ms/step
# Epoch 87/100
# 85/85 - 0s - loss: 0.0014 - 411ms/epoch - 5ms/step
# Epoch 88/100
# 85/85 - 0s - loss: 0.0014 - 430ms/epoch - 5ms/step
# Epoch 89/100
# 85/85 - 0s - loss: 0.0015 - 380ms/epoch - 4ms/step
# Epoch 90/100
# 85/85 - 0s - loss: 0.0014 - 349ms/epoch - 4ms/step
# Epoch 91/100
# 85/85 - 0s - loss: 0.0014 - 354ms/epoch - 4ms/step
# Epoch 92/100
# 85/85 - 0s - loss: 0.0014 - 345ms/epoch - 4ms/step
# Epoch 93/100
# 85/85 - 0s - loss: 0.0013 - 329ms/epoch - 4ms/step
# Epoch 94/100
# 85/85 - 0s - loss: 0.0013 - 320ms/epoch - 4ms/step
# Epoch 95/100
# 85/85 - 0s - loss: 0.0014 - 334ms/epoch - 4ms/step
# Epoch 96/100
# 85/85 - 0s - loss: 0.0013 - 399ms/epoch - 5ms/step
# Epoch 97/100
# 85/85 - 0s - loss: 0.0014 - 388ms/epoch - 5ms/step
# Epoch 98/100
# 85/85 - 0s - loss: 0.0013 - 377ms/epoch - 4ms/step
# Epoch 99/100
# 85/85 - 0s - loss: 0.0014 - 417ms/epoch - 5ms/step
# Epoch 100/100
# 85/85 - 0s - loss: 0.0013 - 397ms/epoch - 5ms/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 3/3 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# Train Score: 19.15 RMSE
# Test Score: 45.44 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
