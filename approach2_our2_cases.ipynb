# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# fix random seed for reproducibility
tf.random.set_seed(7)

# %%
# Use a random dataset for testing
import pandas as pd
import matplotlib.pyplot as plt
dataframe_t1 = pd.read_csv('monkeypox_daily.csv')
dataframe_t2 = dataframe_t1[dataframe_t1['location'] == 'United States']
dataframe = pd.Series(dataframe_t2.new_cases)

plt.plot(dataframe)
plt.show()

# %%
# Change the dataset format to float
dataset = dataframe.values
dataset = dataset.astype('float32')

# print(dataset)

# Normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = dataset.reshape(-1, 1)
print(dataset)
dataset = scaler.fit_transform(dataset)
# Out:
# [[  19.]
#  [   2.]
#  [   4.]
#  [   0.]
#  [   0.]
#  [   7.]
#  [   5.]
#  [   3.]
#  [   9.]
#  [   0.]
#  [   2.]
#  [  14.]
#  [   0.]
#  [   7.]
#  [  12.]
#  [  16.]
#  [  13.]
#  [   0.]
#  [   0.]
#  [   0.]
#  [  29.]
#  [  31.]
#  [   2.]
#  [  24.]
#  [   0.]
#  [   2.]
#  [  43.]
#  [  62.]
#  [  45.]
#  [  45.]
#  [   0.]
#  [   0.]
#  [  64.]
#  [   0.]
#  [ 100.]
#  [  45.]
#  [  94.]
#  [   0.]
#  [   0.]
#  [  67.]
#  [  99.]
#  [  64.]
#  [ 120.]
#  [ 417.]
#  [   0.]
#  [   0.]
#  [ 344.]
#  [ 155.]
#  [ 137.]
#  [ 214.]
#  [ 266.]
#  [   0.]
#  [   0.]
#  [ 299.]
#  [ 597.]
#  [ 103.]
#  [1048.]
#  [ 268.]
#  [   0.]
#  [   0.]
#  [ 278.]
#  [ 650.]
#  [ 482.]
#  [ 291.]
#  [ 485.]
#  [ 427.]
#  [   0.]
#  [   0.]
#  [1392.]
#  [ 558.]
#  [ 900.]
#  [ 365.]
#  [   0.]
#  [   0.]
#  [ 404.]
#  [ 786.]
#  [ 828.]
#  [ 708.]
#  [ 598.]
#  [   0.]
#  [   0.]
#  [   0.]
#  [1307.]
#  [ 521.]
#  [ 636.]
#  [ 452.]
#  [   0.]
#  [   0.]
#  [ 368.]
#  [ 661.]
#  [ 309.]
#  [ 572.]
#  [ 476.]
#  [   0.]
#  [   0.]
#  [ 500.]
#  [   0.]
#  [ 756.]
#  [ 667.]
#  [ 230.]
#  [   0.]
#  [   0.]
#  [   0.]
#  [ 330.]
#  [ 645.]
#  [ 137.]
#  [ 341.]
#  [   0.]
#  [   0.]
#  [ 379.]
#  [ 704.]
#  [   0.]
#  [ 157.]
#  [ 205.]
#  [   0.]
#  [   0.]
#  [ 588.]
#  [ 179.]
#  [ 161.]
#  [ 104.]
#  [   0.]
#  [   0.]
#  [   0.]
#  [ 238.]
#  [1051.]
#  [   0.]
#  [   0.]
#  [   0.]
#  [   0.]
#  [   0.]
#  [   0.]
#  [ 201.]
#  [ 240.]
#  [  74.]
#  [ 220.]
#  [   0.]
#  [   0.]
#  [   0.]
#  [ 239.]
#  [  77.]
#  [   0.]
#  [ 245.]
#  [   0.]
#  [   0.]
#  [   0.]
#  [ 120.]
#  [  57.]
#  [ 183.]
#  [   0.]
#  [   0.]
#  [   0.]
#  [  58.]
#  [ 214.]]

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 102 51

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 10
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# print(trainX)

# for i in range(trainX.shape[0]):
#     print(i, trainX[i, 0], trainY[i])

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 91/91 - 2s - loss: 0.0783 - 2s/epoch - 26ms/step
# Epoch 2/100
# 91/91 - 0s - loss: 0.0586 - 363ms/epoch - 4ms/step
# Epoch 3/100
# 91/91 - 0s - loss: 0.0519 - 475ms/epoch - 5ms/step
# Epoch 4/100
# 91/91 - 0s - loss: 0.0481 - 453ms/epoch - 5ms/step
# Epoch 5/100
# 91/91 - 0s - loss: 0.0449 - 459ms/epoch - 5ms/step
# Epoch 6/100
# 91/91 - 0s - loss: 0.0422 - 472ms/epoch - 5ms/step
# Epoch 7/100
# 91/91 - 1s - loss: 0.0395 - 519ms/epoch - 6ms/step
# Epoch 8/100
# 91/91 - 0s - loss: 0.0371 - 454ms/epoch - 5ms/step
# Epoch 9/100
# 91/91 - 1s - loss: 0.0350 - 622ms/epoch - 7ms/step
# Epoch 10/100
# 91/91 - 0s - loss: 0.0333 - 450ms/epoch - 5ms/step
# Epoch 11/100
# 91/91 - 0s - loss: 0.0314 - 401ms/epoch - 4ms/step
# Epoch 12/100
# 91/91 - 0s - loss: 0.0299 - 433ms/epoch - 5ms/step
# Epoch 13/100
# 91/91 - 0s - loss: 0.0288 - 478ms/epoch - 5ms/step
# Epoch 14/100
# 91/91 - 1s - loss: 0.0278 - 556ms/epoch - 6ms/step
# Epoch 15/100
# 91/91 - 0s - loss: 0.0269 - 447ms/epoch - 5ms/step
# Epoch 16/100
# 91/91 - 0s - loss: 0.0263 - 380ms/epoch - 4ms/step
# Epoch 17/100
# 91/91 - 0s - loss: 0.0257 - 397ms/epoch - 4ms/step
# Epoch 18/100
# 91/91 - 0s - loss: 0.0253 - 498ms/epoch - 5ms/step
# Epoch 19/100
# 91/91 - 0s - loss: 0.0249 - 476ms/epoch - 5ms/step
# Epoch 20/100
# 91/91 - 0s - loss: 0.0245 - 356ms/epoch - 4ms/step
# Epoch 21/100
# 91/91 - 0s - loss: 0.0242 - 315ms/epoch - 3ms/step
# Epoch 22/100
# 91/91 - 0s - loss: 0.0239 - 358ms/epoch - 4ms/step
# Epoch 23/100
# 91/91 - 0s - loss: 0.0239 - 385ms/epoch - 4ms/step
# Epoch 24/100
# 91/91 - 0s - loss: 0.0233 - 384ms/epoch - 4ms/step
# Epoch 25/100
# 91/91 - 0s - loss: 0.0231 - 426ms/epoch - 5ms/step
# Epoch 26/100
# 91/91 - 1s - loss: 0.0227 - 523ms/epoch - 6ms/step
# Epoch 27/100
# 91/91 - 0s - loss: 0.0226 - 420ms/epoch - 5ms/step
# Epoch 28/100
# 91/91 - 0s - loss: 0.0227 - 458ms/epoch - 5ms/step
# Epoch 29/100
# 91/91 - 0s - loss: 0.0224 - 486ms/epoch - 5ms/step
# Epoch 30/100
# 91/91 - 0s - loss: 0.0224 - 354ms/epoch - 4ms/step
# Epoch 31/100
# 91/91 - 0s - loss: 0.0218 - 315ms/epoch - 3ms/step
# Epoch 32/100
# 91/91 - 0s - loss: 0.0219 - 300ms/epoch - 3ms/step
# Epoch 33/100
# 91/91 - 0s - loss: 0.0216 - 359ms/epoch - 4ms/step
# Epoch 34/100
# 91/91 - 0s - loss: 0.0215 - 341ms/epoch - 4ms/step
# Epoch 35/100
# 91/91 - 0s - loss: 0.0213 - 323ms/epoch - 4ms/step
# Epoch 36/100
# 91/91 - 0s - loss: 0.0213 - 357ms/epoch - 4ms/step
# Epoch 37/100
# 91/91 - 0s - loss: 0.0210 - 352ms/epoch - 4ms/step
# Epoch 38/100
# 91/91 - 0s - loss: 0.0209 - 372ms/epoch - 4ms/step
# Epoch 39/100
# 91/91 - 0s - loss: 0.0209 - 315ms/epoch - 3ms/step
# Epoch 40/100
# 91/91 - 0s - loss: 0.0206 - 320ms/epoch - 4ms/step
# Epoch 41/100
# 91/91 - 0s - loss: 0.0208 - 375ms/epoch - 4ms/step
# Epoch 42/100
# 91/91 - 0s - loss: 0.0204 - 374ms/epoch - 4ms/step
# Epoch 43/100
# 91/91 - 0s - loss: 0.0206 - 336ms/epoch - 4ms/step
# Epoch 44/100
# 91/91 - 0s - loss: 0.0203 - 302ms/epoch - 3ms/step
# Epoch 45/100
# 91/91 - 0s - loss: 0.0204 - 313ms/epoch - 3ms/step
# Epoch 46/100
# 91/91 - 0s - loss: 0.0200 - 300ms/epoch - 3ms/step
# Epoch 47/100
# 91/91 - 0s - loss: 0.0197 - 333ms/epoch - 4ms/step
# Epoch 48/100
# 91/91 - 0s - loss: 0.0200 - 400ms/epoch - 4ms/step
# Epoch 49/100
# 91/91 - 0s - loss: 0.0198 - 393ms/epoch - 4ms/step
# Epoch 50/100
# 91/91 - 1s - loss: 0.0196 - 538ms/epoch - 6ms/step
# Epoch 51/100
# 91/91 - 0s - loss: 0.0196 - 406ms/epoch - 4ms/step
# Epoch 52/100
# 91/91 - 0s - loss: 0.0194 - 339ms/epoch - 4ms/step
# Epoch 53/100
# 91/91 - 0s - loss: 0.0194 - 450ms/epoch - 5ms/step
# Epoch 54/100
# 91/91 - 0s - loss: 0.0191 - 400ms/epoch - 4ms/step
# Epoch 55/100
# 91/91 - 0s - loss: 0.0190 - 437ms/epoch - 5ms/step
# Epoch 56/100
# 91/91 - 0s - loss: 0.0190 - 422ms/epoch - 5ms/step
# Epoch 57/100
# 91/91 - 0s - loss: 0.0190 - 386ms/epoch - 4ms/step
# Epoch 58/100
# 91/91 - 0s - loss: 0.0190 - 352ms/epoch - 4ms/step
# Epoch 59/100
# 91/91 - 0s - loss: 0.0187 - 330ms/epoch - 4ms/step
# Epoch 60/100
# 91/91 - 0s - loss: 0.0186 - 429ms/epoch - 5ms/step
# Epoch 61/100
# 91/91 - 0s - loss: 0.0186 - 381ms/epoch - 4ms/step
# Epoch 62/100
# 91/91 - 0s - loss: 0.0185 - 333ms/epoch - 4ms/step
# Epoch 63/100
# 91/91 - 0s - loss: 0.0185 - 301ms/epoch - 3ms/step
# Epoch 64/100
# 91/91 - 0s - loss: 0.0185 - 344ms/epoch - 4ms/step
# Epoch 65/100
# 91/91 - 0s - loss: 0.0182 - 400ms/epoch - 4ms/step
# Epoch 66/100
# 91/91 - 0s - loss: 0.0184 - 358ms/epoch - 4ms/step
# Epoch 67/100
# 91/91 - 0s - loss: 0.0180 - 300ms/epoch - 3ms/step
# Epoch 68/100
# 91/91 - 0s - loss: 0.0180 - 398ms/epoch - 4ms/step
# Epoch 69/100
# 91/91 - 0s - loss: 0.0181 - 365ms/epoch - 4ms/step
# Epoch 70/100
# 91/91 - 0s - loss: 0.0179 - 365ms/epoch - 4ms/step
# Epoch 71/100
# 91/91 - 0s - loss: 0.0180 - 302ms/epoch - 3ms/step
# Epoch 72/100
# 91/91 - 0s - loss: 0.0179 - 297ms/epoch - 3ms/step
# Epoch 73/100
# 91/91 - 0s - loss: 0.0177 - 300ms/epoch - 3ms/step
# Epoch 74/100
# 91/91 - 0s - loss: 0.0177 - 313ms/epoch - 3ms/step
# Epoch 75/100
# 91/91 - 0s - loss: 0.0176 - 288ms/epoch - 3ms/step
# Epoch 76/100
# 91/91 - 0s - loss: 0.0176 - 319ms/epoch - 4ms/step
# Epoch 77/100
# 91/91 - 0s - loss: 0.0175 - 298ms/epoch - 3ms/step
# Epoch 78/100
# 91/91 - 0s - loss: 0.0177 - 298ms/epoch - 3ms/step
# Epoch 79/100
# 91/91 - 0s - loss: 0.0172 - 348ms/epoch - 4ms/step
# Epoch 80/100
# 91/91 - 0s - loss: 0.0173 - 353ms/epoch - 4ms/step
# Epoch 81/100
# 91/91 - 0s - loss: 0.0172 - 334ms/epoch - 4ms/step
# Epoch 82/100
# 91/91 - 0s - loss: 0.0171 - 396ms/epoch - 4ms/step
# Epoch 83/100
# 91/91 - 0s - loss: 0.0173 - 423ms/epoch - 5ms/step
# Epoch 84/100
# 91/91 - 0s - loss: 0.0170 - 304ms/epoch - 3ms/step
# Epoch 85/100
# 91/91 - 0s - loss: 0.0168 - 356ms/epoch - 4ms/step
# Epoch 86/100
# 91/91 - 0s - loss: 0.0170 - 338ms/epoch - 4ms/step
# Epoch 87/100
# 91/91 - 0s - loss: 0.0169 - 359ms/epoch - 4ms/step
# Epoch 88/100
# 91/91 - 0s - loss: 0.0166 - 366ms/epoch - 4ms/step
# Epoch 89/100
# 91/91 - 0s - loss: 0.0168 - 367ms/epoch - 4ms/step
# Epoch 90/100
# 91/91 - 0s - loss: 0.0166 - 381ms/epoch - 4ms/step
# Epoch 91/100
# 91/91 - 0s - loss: 0.0165 - 357ms/epoch - 4ms/step
# Epoch 92/100
# 91/91 - 0s - loss: 0.0165 - 342ms/epoch - 4ms/step
# Epoch 93/100
# 91/91 - 0s - loss: 0.0166 - 368ms/epoch - 4ms/step
# Epoch 94/100
# 91/91 - 0s - loss: 0.0164 - 328ms/epoch - 4ms/step
# Epoch 95/100
# 91/91 - 0s - loss: 0.0165 - 391ms/epoch - 4ms/step
# Epoch 96/100
# 91/91 - 0s - loss: 0.0164 - 371ms/epoch - 4ms/step
# Epoch 97/100
# 91/91 - 0s - loss: 0.0163 - 388ms/epoch - 4ms/step
# Epoch 98/100
# 91/91 - 0s - loss: 0.0161 - 353ms/epoch - 4ms/step
# Epoch 99/100
# 91/91 - 0s - loss: 0.0162 - 351ms/epoch - 4ms/step
# Epoch 100/100
# 91/91 - 0s - loss: 0.0161 - 311ms/epoch - 3ms/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 3/3 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# Train Score: 172.92 RMSE
# Test Score: 206.02 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
